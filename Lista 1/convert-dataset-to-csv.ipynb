# %%
import pandas as pd
import re
import regex
import nltk
import matplotlib.pyplot as plt
import numpy as np

# %%
import os
folder_path = 'drive/MyDrive/NLP/Processamento de Linguagem Natural/bbc/'
folders = ['business', 'entertainment', 'politics', 'sport', 'tech']

files = []
counter = 0
for folder in folders:
  for file in os.listdir(folder_path+folder):
    with open(folder_path+folder+'/'+file) as f:
      lines = f.readlines()
      print(folder, file)
      title = lines[0]
      article = ''.join(lines[2:])
      files.append([file, title, article, folder]) # [filename, title, article, label]
      '''
      if counter < 5:
        counter+=1
      else:
        break
        '''
df = pd.DataFrame(files, columns=['filename', 'title', 'article', 'target'])
df.to_csv(folder_path+'files_and_targets.csv')
# Out:
# business 289.txt
# business 504.txt
# business 262.txt
# business 276.txt
# business 510.txt
# business 060.txt
# business 074.txt
# business 048.txt
# business 114.txt
# business 100.txt
# business 128.txt
# business 470.txt
# business 316.txt
# business 302.txt
# business 464.txt
# business 458.txt
# business 459.txt
# business 303.txt
# business 465.txt
# business 471.txt
# business 317.txt
# business 129.txt
# business 101.txt
# business 115.txt
# business 049.txt
# business 075.txt
# business 061.txt
# business 277.txt
# business 505.txt
# business 263.txt
# business 288.txt
# business 275.txt
# business 261.txt
# business 507.txt
# business 249.txt
# business 088.txt
# business 077.txt
# business 063.txt
# business 103.txt
# business 117.txt
# business 498.txt
# business 467.txt
# business 301.txt
# business 315.txt
# business 473.txt
# business 329.txt
# business 328.txt
# business 314.txt
# business 472.txt
# business 466.txt
# business 300.txt
# business 499.txt
# ...

# %%
df.head()
# Out:
#   filename                                title  \
# 0  289.txt    UK economy facing 'major risks'\n
# 1  504.txt  Aids and climate top Davos agenda\n
# 2  262.txt   Asian quake hits European shares\n
# 3  276.txt   India power shares jump on debut\n
# 4  510.txt    Lacroix label bought by US firm\n
#
#                                              article    target
# 0  The UK manufacturing sector will continue to f...  business
# 1  Climate change and the fight against Aids are ...  business
# 2  Shares in Europe's leading reinsurers and trav...  business
# 3  Shares in India's largest power producer, Nati...  business
# 4  Luxury goods group LVMH has sold its loss-maki...  business
